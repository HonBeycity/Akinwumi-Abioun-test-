# %% [markdown]
# AKINWUMI ABIODUN AKINTUNDE
# MRAKINWUMIA@GMAIL.COM
# 07030090016

# %% [markdown]
# QUESTION NO 1
#
# What is Data science ? this is the collection of informtion using different means to make informed decision.
#
# what is science anaysis ? data analysis is the process of obtaining infrmation, cleaning and transforming such information with the aim of making use of such information.
#
# Data life cycle talks about the usefulnes of a particular set of that at different stages of life.
#
# Tools used in Data Analyses includes; PYTHON, POWER BI, EXCEL E.T.C

# %% [markdown]
# QUESTION NO 2. CREATE A TABLE OF 10 ROWS AND 3 COLUMNS, PLOT A GRAPH WITH IT.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
A ={'alcohol':['Orijin', 'Stout', 'Gulder', 'Campari', 'Alomo', 'Star', 'Desperado', 'Tiger', 'Jack', 'Trophy'],
     'volum':[40,87,87, 98, 99, 96, 92, 80, 50, 37],
    'state':['Ekiti', 'Osun', 'Ogun', 'Kwara', 'lagos', 'Oyo', 'Ebonyi', 'Anambra', 'Yobe','Kaduna']}

# %%
df=pd.DataFrame(A)

# %%
df
# Out:
#      alcohol  volum    state
# 0     Orijin     40    Ekiti
# 1      Stout     87     Osun
# 2     Gulder     87     Ogun
# 3    Campari     98    Kwara
# 4      Alomo     99    lagos
# 5       Star     96      Oyo
# 6  Desperado     92   Ebonyi
# 7      Tiger     80  Anambra
# 8       Jack     50     Yobe
# 9     Trophy     37   Kaduna

# %%
df['volum'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df['alcohol'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['state'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['volum'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
